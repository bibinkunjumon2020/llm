# %% [markdown]
# <a href="https://colab.research.google.com/github/bibinkunjumon2020/llm/blob/main/MoE_in_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mixtral in Colab
#
# Welcome! In this notebook you can run [Mixtral8x7B-Instruct](https://huggingface.co/mistralai/Mixtral-8x7B-v0.1) with decent generation speed **right in Google Colab or on a consumer-grade GPU**. This was made possible by quantizing the original model in mixed precision and implementing a MoE-specific offloading strategy.
#
# To learn more, read our [tech report](https://arxiv.org/abs/2312.17238) or check out the [repo](https://github.com/dvmazur/mixtral-offloading) on GitHub.

# %% [markdown]
# One will need approximately 16 GB of VRAM and 11 GB of RAM to run this notebook and generate somewhat long texts.
#
#
# <details>
#
# <summary>How to balance between RAM and GPU VRAM usage</summary>
#
# You can balance between RAM and GPU VRAM usage by changing <code>offload_per_layer</code> variable in the <a href="#scrollTo=_mIpePTMFyRY&line=10&uniqifier=1">Initialize model</a> section. Increasing <code>offload_per_layer</code> will decrease GPU VRAM usage, increase RAM usage and decrease generation speed. Decreasing <code>offload_per_layer</code> will have the opposite effect.
#
# Note that this notebook should run normally in Google Colab with <code>offload_per_layer = 4</code>, but may crush with other values. However, if you run this somewhere else, you're free to play with this variable.
# </details>

# %% [markdown]
# ## Install and import libraries

# %%
# fix numpy in colab
import numpy
from IPython.display import clear_output

# fix triton in colab
# !export LC_ALL="en_US.UTF-8"
# !export LD_LIBRARY_PATH="/usr/lib64-nvidia"
# !export LIBRARY_PATH="/usr/local/cuda/lib64/stubs"
# !ldconfig /usr/lib64-nvidia

# !git clone https://github.com/dvmazur/mixtral-offloading.git --quiet
# !cd mixtral-offloading && pip install -q -r requirements.txt
# !huggingface-cli download lavawolfiee/Mixtral-8x7B-Instruct-v0.1-offloading-demo --quiet --local-dir Mixtral-8x7B-Instruct-v0.1-offloading-demo

# clear_output()
# Out:
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 33.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 38.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 46.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 43.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.4 MB/s eta 0:00:00
#   Building wheel for hqq (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# /content/Mixtral-8x7B-Instruct-v0.1-offloading-demo

# %%
import sys

sys.path.append("mixtral-offloading")
import torch
from torch.nn import functional as F
from hqq.core.quantize import BaseQuantizeConfig
from huggingface_hub import snapshot_download
from IPython.display import clear_output
from tqdm.auto import trange
from transformers import AutoConfig, AutoTokenizer
from transformers.utils import logging as hf_logging

from src.build_model import OffloadConfig, QuantConfig, build_model
# Out:
# hqq_aten package not installed. HQQBackend.ATEN backend will not work unless you install the hqq_aten lib in hqq/kernels.
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Initialize model

# %%
model_name = "mistralai/Mixtral-8x7B-Instruct-v0.1"
quantized_model_name = "lavawolfiee/Mixtral-8x7B-Instruct-v0.1-offloading-demo"
state_path = "Mixtral-8x7B-Instruct-v0.1-offloading-demo"

config = AutoConfig.from_pretrained(quantized_model_name)

device = torch.device("cuda:0")

##### Change this to 5 if you have only 12 GB of GPU VRAM #####
offload_per_layer = 4
# offload_per_layer = 5
###############################################################

num_experts = config.num_local_experts

offload_config = OffloadConfig(
    main_size=config.num_hidden_layers * (num_experts - offload_per_layer),
    offload_size=config.num_hidden_layers * offload_per_layer,
    buffer_size=4,
    offload_per_layer=offload_per_layer,
)


attn_config = BaseQuantizeConfig(
    nbits=4,
    group_size=64,
    quant_zero=True,
    quant_scale=True,
)
attn_config["scale_quant_params"]["group_size"] = 256


ffn_config = BaseQuantizeConfig(
    nbits=2,
    group_size=16,
    quant_zero=True,
    quant_scale=True,
)
quant_config = QuantConfig(ffn_config=ffn_config, attn_config=attn_config)


model = build_model(
    device=device,
    quant_config=quant_config,
    offload_config=offload_config,
    state_path=state_path,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/init.py:412: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Loading experts:   0%|          | 0/32 [00:00<?, ?it/s]

# %% [markdown]
# ## Run the model

# %%
from transformers import TextStreamer


tokenizer = AutoTokenizer.from_pretrained(model_name)
streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)
past_key_values = None
sequence = None

seq_len = 0
while True:
  print("User: ", end="")
  user_input = input()
  print("\n")

  user_entry = dict(role="user", content=user_input)
  input_ids = tokenizer.apply_chat_template([user_entry], return_tensors="pt").to(device)

  if past_key_values is None:
    attention_mask = torch.ones_like(input_ids)
  else:
    seq_len = input_ids.size(1) + past_key_values[0][0][0].size(1)
    attention_mask = torch.ones([1, seq_len - 1], dtype=torch.int, device=device)

  print("Mixtral: ", end="")
  result = model.generate(
    input_ids=input_ids,
    attention_mask=attention_mask,
    past_key_values=past_key_values,
    streamer=streamer,
    do_sample=True,
    temperature=0.9,
    top_p=0.9,
    max_new_tokens=512,
    pad_token_id=tokenizer.eos_token_id,
    return_dict_in_generate=True,
    output_hidden_states=True,
  )
  print("\n")

  sequence = result["sequences"]
  past_key_values = result["past_key_values"]
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# User: where is india?
#
#
# Mixtral: India is located in Southern Asia, bordering the Arabian Sea to the southwest, and the Bay of Bengal to the southeast. It shares land borders with Pakistan to the west, China to the northeast, Nepal to the north, Bhutan to the northwest, Bangladesh to the east, and Myanmar to the east.
#
# India is the seventh-largest country by land area, the third-largest by purchasing power parity, and the second-most populous country in the world, with over a billion people. It is also the world's largest democracy.
#
# India has a rich and diverse culture, with a history that stretches back over 5,000 years. It is known for its contributions to art, science, religion, and philosophy, as well as its achievements in technology, trade, and industry. India is a rapidly developing country, with a diverse economy that is based on manufacturing, agriculture, and services.
#
# India is a popular tourist destination, known for its beautiful landscapes, vibrant cities, and rich cultural heritage. Some of the most famous tourist attractions in India include the Taj Mahal, the Ajanta and Ellora caves, the Meenakshi Temple, the Jaipur Palace, and the beaches of Goa.
#
#
# User: what was my last question
#
#
# Mixtral: Your last question was "where is india?". I provided an answer to that question in my previous response.
#
#
# User: which ml model can be used for ai font generation based on user text input
#
#
# Mixtral: There are a few different machine learning (ML) models that could be used for generating fonts based on user input. Here are a few options:
#
# 1. **Generative Adversarial Networks (GANs)**: GANs are a type of deep learning model that consist of two parts: a generator and a discriminator. The generator is trained to produce new data that is similar to a training dataset, while the discriminator is trained to distinguish between real data and the fake data produced by the generator. In the context of font generation, a GAN could be trained on a dataset of font images, and then used to generate new fonts that are similar to the training set.
# 2. **Variational Autoencoders (VAEs)**: VAEs are another type of deep learning model that can be used for generating new data. They consist of an encoder and a decoder. The encoder is trained to encode the input data into a lower-dimensional space, called a latent space, while the decoder is trained to decode the latent space back into the original input space. In the context of font generation, a VAE could be trained on a dataset of font images and then used to generate new fonts by sampling from the latent space.
# 3. **Transformer models**: Transformer models are a type of neural network that are well-suited for tasks that involve processing sequential data, such as natural language processing (NLP) tasks. They have been used for a variety of NLP tasks, such as machine translation, text classification, and text generation. In the context of font generation, a transformer model could be trained on a dataset of font images and then used to generate new fonts by generating sequences of characters.
#
# Ultimately, the choice of model will depend on the specific requirements of your application and the resources available to you. It is also worth noting that these models can be quite complex and require a significant amount of training data and computational resources to train. If you are not familiar with these models, it may be helpful to work with an experienced machine learning engineer or data scientist.
#
#
# User: can you explain the above question
#
#
# Mixtral: Sure! I'd be happy to explain the answer to your question about using machine learning (ML) models for generating fonts based on user input.
#
# First, let me define a few terms that I used in my previous response:
#
# * **Generative Adversarial Networks (GANs)**: GANs are a type of deep learning model that consist of two parts: a generator and a discriminator. The generator is trained to produce new data that is similar to a training dataset, while the discriminator is trained to distinguish between real data and the fake data produced by the generator. In the context of font generation, a GAN could be trained on a dataset of font images, and then used to generate new fonts that are similar to the training set.
# * **Variational Autoencoders (VAEs)**: VAEs are another type of deep learning model that can be used for generating new data. They consist of an encoder and a decoder. The encoder is trained to encode the input data into a lower-dimensional space, called a latent space, while the decoder is trained to decode the latent space back into the original input space. In the context of font generation, a VAE could be trained on a dataset of font images and then used to generate new fonts by sampling from the latent space.
# * **Transformer models**: Transformer models are a type of neural network that are well-suited for tasks that involve processing sequential data, such as natural language processing (NLP) tasks. They have been used for a variety of NLP tasks, such as machine translation, text classification, and text generation. In the context of font generation, a transformer model could be trained on a dataset of font images and then used to generate new fonts by generating sequences of characters.
#
# Now, let me explain the process of using these models for font generation.
#
# First, you would need to gather a dataset of font images to train the model on. This dataset could be created by manually collecting images of fonts from the web or by using a tool to automatically scrape font images from a website.
#
# Next, you would train one of the models I mentioned above on the dataset of font images. This process involves feeding the model the font images and adjusting the model's parameters to minimize the difference between the model's predictions and the actual values of the training data.
#
# Once the
#
#
# User: continue
#
#
# Mixtral: Once the model has been trained on the dataset of font images, you can use it to generate new fonts based on user input.
#
# To do this, you would first preprocess the user input to convert it into a format that the model can understand. For example, if the user inputs a string of text, you might need to convert each character in the string into a vector of numerical values that can be fed into the model.
#
# Next, you would feed the preprocessed user input into the model and use the model to generate the new font. This process might involve sampling from the model's latent space or using the model to generate a sequence of characters that form the new font.
#
# Finally, you would postprocess the output of the model to convert it back into a form that is easy for the user to understand. For example, you might convert the model's output into a series of images that can be displayed as a new font.
#
# I hope this helps to clarify the process of using machine learning models for font generation! If you have any further questions, please don't hesitate to ask.
#
#
# User: Which is the best llms as of today?
#
#
# Mixtral: It's difficult to say which is the "best" learning management system (LMS) because there are many different LMSs available, and each one has its own strengths and weaknesses. The best LMS for a particular organization or individual will depend on their specific needs, budget, and preferences.
#
# That being said, here are a few LMSs that are highly rated and widely used:
#
# 1. **Canvas**: Canvas is a cloud-based LMS that is designed for educational institutions and businesses. It offers features such as course management, grading, analytics, and collaboration tools. Canvas is known for its user-friendly interface and its robust set of features.
# 2. **Blackboard Learn**: Blackboard Learn is a web-based LMS that is used by many educational institutions. It offers features such as course management, grading, analytics, and collaboration tools. Blackboard Learn is known for its scalability and its ability to integrate with a wide range of third-party tools.
# 3. **Moodle**: Moodle is a free and open-source LMS that is used by many educational institutions and businesses. It offers features such as course management, grading, analytics, and collaboration tools. Moodle is known for its flexibility and its large community of users and developers.
# 4. **Google Classroom**: Google Classroom is a free LMS that is part of the Google Workspace for Education suite. It offers features such as course management, grading, and collaboration tools. Google Classroom is known for its seamless integration with other Google Workspace tools, such as Google Drive and Google Docs.
# 5. **Salesforce Learning Platform**: The Salesforce Learning Platform is a cloud-based LMS that is designed for businesses. It offers features such as course management, grading, analytics, and collaboration tools. The Salesforce Learning Platform is known for its strong security features and its integration with the Salesforce CRM platform.
#
# I recommend researching each of these LMSs and comparing their features, pricing, and user reviews to determine which one is the best fit for your needs. It's also a good idea to take advantage of free trials and demos when they are available, as this will give you a better idea of how each LMS works in practice.
#
#
# User: hi
#
#
# Mixtral: Hello! How can I help you today? If you have a question, feel free to ask! I'm here to help.
#
# Is there a particular topic you'd like me to explain or provide information about? I'm happy to help with a wide range of subjects, including:
#
# * Natural language processing (NLP)
# * Deep learning
# * Neural networks
# * Machine learning (ML)
# * Artificial intelligence (AI)
# * Data science
# * Statistics
# * Mathematics
# * Programming
# * Data analysis
# * Data visualization
# * Data engineering
# * Database management
# * Cloud computing
# * And much more!
#
# Just let me know if you have any questions or if there's something specific you'd like me to explain. I'll do my best to provide a clear and concise answer.
#
# If you're not sure what you'd like to ask, you might find it helpful to know that I can provide definitions for technical terms, explain concepts and technologies, compare and contrast different approaches, provide code examples, and much more. I'm here to help you learn and understand!
#
# Don't hesitate to ask me anything you want to know! I'm happy to help, and I'll do my best to provide a thorough and helpful answer.
#
#
# User:
#
#
# Mixtral: Hello again! Is there something specific you'd like to ask or learn about? I'm here to help with a wide range of topics, including:
#
# * Natural language processing (NLP)
# * Deep learning
# * Neural networks
# * Machine learning (ML)
# * Artificial intelligence (AI)
# * Data science
# * Statistics
# * Mathematics
# * Programming
# * Data analysis
# * Data visualization
# * Data engineering
# * Database management
# * Cloud computing
# * And much more!
#
# Just let me know if you have any questions or if there's something specific you'd like me to explain. I'll do my best to provide a clear and concise answer.
#
# If you're not sure what you'd like to ask, you might find it helpful to know that I can provide definitions for technical terms, explain concepts and technologies, compare and contrast different approaches, provide code examples, and much more. I'm here to help you learn and understand!
#
# Don't hesitate to ask me anything you want to know! I'm happy to help. Is there a particular topic you're interested in? I'd be happy to provide more information or answer any questions you have.
#
#
# User: how much gpu are you using now for generating responmse
#
#
# Mixtral: I don't use a GPU to generate responses. I am a language model that is trained on a large dataset of text and is able to generate responses based on patterns and information learned from that dataset. I am able to generate responses quickly and efficiently without the need for a GPU.
#
# That being said, I should note that I am a large language model that requires a significant amount of computing resources to train. I am trained on a large cluster of machines, each of which is equipped with multiple GPUs. These GPUs are used to speed up the training process by performing matrix multiplication and other computations in parallel. However, once I am trained, I can generate responses on a single machine without the need for a GPU.
#
# I hope this helps to clarify the role that GPUs play in the process of training and deploying a language model like me. If you have any further questions, please don't hesitate to ask!
#
#
# User: exit
